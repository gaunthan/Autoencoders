# %% [markdown]
# ## Import the libraries

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib inline

from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, add
from keras.objectives import binary_crossentropy
from keras.layers.core import Layer, Dense, Dropout, Activation, Flatten, Reshape
from keras.utils import np_utils
from keras import backend as K
from keras import metrics
from keras.layers.core import Lambda
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load the data

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data('D:\Documents\Datasets\mnist\mnist.npz')

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %% [markdown]
# ## Normalize the data

# %% [markdown]
# We want the pixels values between 0 and 1 instead of between 0 and 255

# %%
X_train = X_train.astype("float32")/255.
X_test = X_test.astype("float32")/255.

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Flatten the images for the Fully-Connected Networks

# %%
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.reshape((len(X_test), np.prod(X_test.shape[1:])))

# %% [markdown]
# ___

# %% [markdown]
# # **Simple Autoencoder**

# %% [markdown]
# ### Create the network

# %% [markdown]
# The first network is the most simple autoencoder. It has three layers : Input - encoded - decoded

# %%
input_size = 784
hidden_size = 128
code_size = 2

x = Input(shape=(input_size,))
hidden_1 = Dense(hidden_size, activation='relu')(x)
h = Dense(code_size)(hidden_1)
hidden_2 = Dense(hidden_size, activation='relu')(h)
r = Dense(input_size, activation='sigmoid')(hidden_2)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
# Out:
# WARNING:tensorflow:From C:\Softwares\Development\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(autoencoder).create(prog='dot', format='svg'))

# %% [markdown]
# ### Train the network

# %%
epochs = 50
batch_size = 128

# %%
history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, X_test))
# Out:
# WARNING:tensorflow:From C:\Softwares\Development\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.2527 - val_loss: 0.2202
# Epoch 2/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.2147 - val_loss: 0.2084
# Epoch 3/50
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.2061 - val_loss: 0.2031
# Epoch 4/50
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.2019 - val_loss: 0.2000
# Epoch 5/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1992 - val_loss: 0.1976
# Epoch 6/50
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.1971 - val_loss: 0.1961
# Epoch 7/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.1956 - val_loss: 0.1948
# Epoch 8/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.1942 - val_loss: 0.1934
# Epoch 9/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.1931 - val_loss: 0.1925
# Epoch 10/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.1922 - val_loss: 0.1917
# Epoch 11/50
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.1913 - val_loss: 0.1911
# Epoch 12/50
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.1905 - val_loss: 0.1904
# Epoch 13/50
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.1897 - val_loss: 0.1895
# Epoch 14/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.1890 - val_loss: 0.1890
# Epoch 15/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.1884 - val_loss: 0.1887
# Epoch 16/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1878 - val_loss: 0.1880
# Epoch 17/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1873 - val_loss: 0.1880
# Epoch 18/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.1869 - val_loss: 0.1875
# Epoch 19/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1864 - val_loss: 0.1867
# Epoch 20/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1860 - val_loss: 0.1867
# Epoch 21/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.1856 - val_loss: 0.1863
# Epoch 22/50
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.1852 - val_loss: 0.1860
# Epoch 23/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.1849 - val_loss: 0.1857
# Epoch 24/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.1845 - val_loss: 0.1854
# Epoch 25/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.1842 - val_loss: 0.1853
# Epoch 26/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.1839 - val_loss: 0.1850
# Epoch 27/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.1836 - val_loss: 0.1849
# Epoch 28/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1833 - val_loss: 0.1845
# Epoch 29/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.1831 - val_loss: 0.1844
# Epoch 30/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.1828 - val_loss: 0.1842
# Epoch 31/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.1825 - val_loss: 0.1841
# Epoch 32/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.1823 - val_loss: 0.1838
# Epoch 33/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.1821 - val_loss: 0.1839
# Epoch 34/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.1819 - val_loss: 0.1833
# Epoch 35/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 0.1816 - val_loss: 0.1836
# Epoch 36/50
# 60000/60000 [==============================] - 5s 77us/step - loss: 0.1814 - val_loss: 0.1832
# Epoch 37/50
# 60000/60000 [==============================] - 5s 77us/step - loss: 0.1813 - val_loss: 0.1832
# Epoch 38/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 0.1811 - val_loss: 0.1832
# Epoch 39/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1809 - val_loss: 0.1830
# Epoch 40/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1807 - val_loss: 0.1829
# Epoch 41/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.1805 - val_loss: 0.1828
# Epoch 42/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.1804 - val_loss: 0.1827
# Epoch 43/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.1802 - val_loss: 0.1825
# Epoch 44/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.1800 - val_loss: 0.1823
# Epoch 45/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.1798 - val_loss: 0.1822
# Epoch 46/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1797 - val_loss: 0.1821
# Epoch 47/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.1796 - val_loss: 0.1819
# Epoch 48/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.1794 - val_loss: 0.1820
# Epoch 49/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.1793 - val_loss: 0.1818
# Epoch 50/50
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.1792 - val_loss: 0.1818

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Plot the 2D Latent representation

# %%
encoder = Model(x, h)

# %%
x_test_encoded = encoder.predict(X_test, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# # **Variational Autoencoder**

# %%
original_dim = 784
latent_dim = 2
intermediate_dim = 256
epsilon_std = 1.0

# %%
x = Input(shape=(original_dim,))
h = Dense(intermediate_dim, activation='relu')(x)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

# %%
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0., stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# %%
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

decoder_h = Dense(intermediate_dim, activation='relu')
decoder_mean = Dense(original_dim, activation='sigmoid')
h_decoded = decoder_h(z)
x_decoded_mean = decoder_mean(h_decoded)

# %%
def vae_loss(x, x_decoded_mean):
    xent_loss = original_dim * binary_crossentropy(x, x_decoded_mean)
    kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return K.mean(xent_loss + kl_loss)

# %%
vae = Model(x, x_decoded_mean)
vae.compile(optimizer='rmsprop', loss = vae_loss)
vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          200960      input_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            514         dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            514         dense_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 2)            0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 256)          768         lambda_1[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 784)          201488      dense_8[0][0]
# ==================================================================================================
# Total params: 404,244
# Trainable params: 404,244
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(vae).create(prog='dot', format='svg'))

# %%
history = vae.fit(X_train, X_train,shuffle=True, epochs=epochs, batch_size=batch_size, validation_data=(X_test, X_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 192.7459 - val_loss: 172.9135
# Epoch 2/50
# 60000/60000 [==============================] - 4s 71us/step - loss: 170.9964 - val_loss: 169.3507
# Epoch 3/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 167.2540 - val_loss: 166.5410
# Epoch 4/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 164.8509 - val_loss: 164.2894
# Epoch 5/50
# 60000/60000 [==============================] - 5s 89us/step - loss: 163.0197 - val_loss: 162.8920
# Epoch 6/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 161.4645 - val_loss: 162.0145
# Epoch 7/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 160.1841 - val_loss: 159.8950
# Epoch 8/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 159.1297 - val_loss: 159.0741
# Epoch 9/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 158.2522 - val_loss: 158.4538
# Epoch 10/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 157.5293 - val_loss: 157.8667
# Epoch 11/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 156.9189 - val_loss: 156.9272
# Epoch 12/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 156.3489 - val_loss: 156.8250
# Epoch 13/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 155.9140 - val_loss: 156.1734
# Epoch 14/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 155.5132 - val_loss: 156.0273
# Epoch 15/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 155.1628 - val_loss: 155.5045
# Epoch 16/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 154.8365 - val_loss: 155.5429
# Epoch 17/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 154.5383 - val_loss: 155.3226
# Epoch 18/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 154.2901 - val_loss: 155.1909
# Epoch 19/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 154.0349 - val_loss: 155.0027
# Epoch 20/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 153.7939 - val_loss: 154.4848
# Epoch 21/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 153.5663 - val_loss: 155.1700
# Epoch 22/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 153.3693 - val_loss: 154.5534
# Epoch 23/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 153.1550 - val_loss: 154.3366
# Epoch 24/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 152.9746 - val_loss: 154.5231
# Epoch 25/50
# 60000/60000 [==============================] - 5s 91us/step - loss: 152.7766 - val_loss: 154.0591
# Epoch 26/50
# 60000/60000 [==============================] - 5s 91us/step - loss: 152.6004 - val_loss: 153.9013
# Epoch 27/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 152.4466 - val_loss: 153.5200
# Epoch 28/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 152.2910 - val_loss: 153.5579
# Epoch 29/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 152.1217 - val_loss: 153.4336
# Epoch 30/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 151.9894 - val_loss: 153.4478
# Epoch 31/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 151.8301 - val_loss: 153.4726
# Epoch 32/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 151.6969 - val_loss: 153.2725
# Epoch 33/50
# 60000/60000 [==============================] - 5s 77us/step - loss: 151.5728 - val_loss: 153.2841
# Epoch 34/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 151.4527 - val_loss: 152.9854
# Epoch 35/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 151.3195 - val_loss: 153.1126
# Epoch 36/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 151.1837 - val_loss: 154.2407
# Epoch 37/50
# 60000/60000 [==============================] - 4s 75us/step - loss: 151.0969 - val_loss: 152.5947
# Epoch 38/50
# 60000/60000 [==============================] - 5s 75us/step - loss: 150.9591 - val_loss: 152.6176
# Epoch 39/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 150.8609 - val_loss: 152.6804
# Epoch 40/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 150.7246 - val_loss: 152.5875
# Epoch 41/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 150.6306 - val_loss: 152.5901
# Epoch 42/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 150.5146 - val_loss: 152.3019
# Epoch 43/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 150.4125 - val_loss: 152.3771
# Epoch 44/50
# 60000/60000 [==============================] - 5s 76us/step - loss: 150.3339 - val_loss: 152.2271
# Epoch 45/50
# 60000/60000 [==============================] - 5s 76us/step - loss: 150.2189 - val_loss: 152.5210
# Epoch 46/50
# 60000/60000 [==============================] - 5s 76us/step - loss: 150.1390 - val_loss: 152.4907
# Epoch 47/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 150.0643 - val_loss: 152.5108
# Epoch 48/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 149.9665 - val_loss: 152.3004
# Epoch 49/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 149.8908 - val_loss: 152.5547
# Epoch 50/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 149.8048 - val_loss: 153.0307

# %% [markdown]
# ## Plot the losses

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Plot the 2D latent representation

# %%
# build a model to project inputs on the latent space
encoder = Model(x, z_mean)

# display a 2D plot of the digit classes in the latent space
x_test_encoded = encoder.predict(X_test, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()

# %%
# build a digit generator that can sample from the learned distribution
decoder_input = Input(shape=(latent_dim,))
_h_decoded = decoder_h(decoder_input)
_x_decoded_mean = decoder_mean(_h_decoded)
generator = Model(decoder_input, _x_decoded_mean)

# %%
# display a 2D manifold of the digits
n = 20  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# linearly spaced coordinates on the unit square were transformed through the inverse CDF (ppf) of the Gaussian
# to produce values of the latent variables z, since the prior of the latent space is Gaussian
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
